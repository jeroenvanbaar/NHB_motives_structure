# %%
import pandas as pd

# %%
gameDat_study1 = pd.read_csv('gameDat_study1.csv',index_col=0)
gameDat_study1.head()
# Out:
#    sub  subID  Block Player Type Variant Type_Total  Trial  S   T GameType  \
# 0    3   2003      0   G.P.  opt     nat    opt_nat      0  3  12       PD
# 1    3   2003      0   G.P.  opt     nat    opt_nat      1  7   8       HG
# 2    3   2003      0   G.P.  opt     nat    opt_nat      2  3   8       SH
# 3    3   2003      0   G.P.  opt     nat    opt_nat      3  7  12       SG
# 4    3   2003      0   G.P.  opt     nat    opt_nat      4  0  15       PD
#
#             Colors CorrAns GivenAns  ConfidenceNum  ScoreNum  RT_radio  \
# 0  ['Blue', 'Red']     def      def             70         1     10439
# 1  ['Blue', 'Red']    coop     coop             80         1      5259
# 2  ['Blue', 'Red']    coop     coop             80         1      2764
# 3  ['Blue', 'Red']     def      def             80         1      4497
# 4  ['Blue', 'Red']     def      def             70         1     12523
#
#    RT_submit          SelfReport
# 0      14310  maximize own score
# ...

# %%
gameDat_study2 = pd.read_csv('gameDat_study2.csv',index_col=0)
gameDat_study2.head()
# Out:
#    sub  subID  Block Player Type Variant Type_Total  Trial   S   T GameType  \
# 0    5   5005      0   N.N.  opt     nat    opt_nat      0   0  12       PD
# 1    5   5005      0   N.N.  opt     nat    opt_nat      1   7   5       HG
# 2    5   5005      0   N.N.  opt     nat    opt_nat      2  10  12       SG
# 3    5   5005      0   N.N.  opt     nat    opt_nat      3   3   5       SH
# 4    5   5005      0   N.N.  opt     nat    opt_nat      4   0   8       SH
#
#                Colors CorrAns GivenAns  ConfidenceNum  ScoreNum  RT_radio  \
# 0  ['Not', 'Defined']     def      def             86         1      8631
# 1  ['Not', 'Defined']    coop     coop             70         1      3639
# 2  ['Not', 'Defined']     def     coop             52         0      4796
# 3  ['Not', 'Defined']    coop      def             52         0      3840
# 4  ['Not', 'Defined']    coop     coop             54         1      3806
#
#    RT_submit   SelfReport
# 0      10443  not defined
# ...

# %%
gameDat_study4 = pd.read_csv('gameDat_study4.csv',index_col=0)
gameDat_study4 = gameDat_study4.drop(columns = ['worker','assignment','ScoreCumulBlock'])
gameDat_study4.head()
# Out:
#    sub  subID  Block Player  Type Variant Type_Total  Trial   S   T GameType  \
# 0    1   6001      0   n.a.  pess     nat   pess_nat      0   7  15       SG
# 1    1   6001      0   n.a.  pess     nat   pess_nat      1   3  15       PD
# 2    1   6001      0   n.a.  pess     nat   pess_nat      2   3   8       SH
# 3    1   6001      0   n.a.  pess     nat   pess_nat      3   7   5       HG
# 4    1   6001      0   n.a.  pess     nat   pess_nat      4  10  15       SG
#
#   Colors CorrAns GivenAns  ConfidenceNum  ScoreNum  RT_radio  RT_submit  \
# 0   n.a.    coop     coop           50.0         1   34851.0    38989.0
# 1   n.a.     def      def           50.0         1   20870.0    24642.0
# 2   n.a.     def      def           50.0         1    7268.0     9664.0
# 3   n.a.    coop     coop           70.0         1    8997.0    11736.0
# 4   n.a.    coop     coop           60.0         1    5880.0     8617.0
#
#   SelfReport
# 0       n.a.
# 1       n.a.
# 2       n.a.
# ...

# %%
gameDat_total = gameDat_study1.append(gameDat_study2).append(gameDat_study4)
gameDat_total.head()
# Out:
#    sub  subID  Block Player Type Variant Type_Total  Trial  S   T GameType  \
# 0    3   2003      0   G.P.  opt     nat    opt_nat      0  3  12       PD
# 1    3   2003      0   G.P.  opt     nat    opt_nat      1  7   8       HG
# 2    3   2003      0   G.P.  opt     nat    opt_nat      2  3   8       SH
# 3    3   2003      0   G.P.  opt     nat    opt_nat      3  7  12       SG
# 4    3   2003      0   G.P.  opt     nat    opt_nat      4  0  15       PD
#
#             Colors CorrAns GivenAns  ConfidenceNum  ScoreNum  RT_radio  \
# 0  ['Blue', 'Red']     def      def           70.0         1   10439.0
# 1  ['Blue', 'Red']    coop     coop           80.0         1    5259.0
# 2  ['Blue', 'Red']    coop     coop           80.0         1    2764.0
# 3  ['Blue', 'Red']     def      def           80.0         1    4497.0
# 4  ['Blue', 'Red']     def      def           70.0         1   12523.0
#
#    RT_submit          SelfReport
# 0    14310.0  maximize own score
# ...

# %%
gameDat_total.shape
# Out:
# (25792, 19)

# %%
150*64 + 50*128 + 153*64
# Out:
# 25792

# %% [markdown]
# It checks out.

# %%
gameDat_total.to_csv('gameDat_total.csv')
